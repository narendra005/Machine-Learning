# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Understanding Statictics 40 Minites Read

# %% [markdown]
# ## Wikipedia defines it as the study of the collection, analysis, interpretation, presentation, and organization of data. Therefore, it shouldn’t be a surprise that data scientists need to know statistics.

# %% [markdown]
# What is Statistics?
# #Statistics is a set of mathematical methods and tools that enable us to answer important questions about data. It is divided into two categories:
#
# 1. Descriptive Statistics - this offers methods to summarise data by transforming raw observations into meaningful information that is easy to interpret and share.
# 1. Inferential Statistics - this offers methods to study experiments done on small samples of data and chalk out the inferences to the entire population (entire domain).

# %% [markdown]
# ## Central Tendency
#
#
# 1. Mean: The average of the dataset.
# 2. Median: The middle value of an ordered dataset.( 1, 5 , 7 , 1,13) Median would be 7
# 3. Mode: The most frequent value in the dataset. If the data have multiple values that occurred the most frequently, we have a multimodal distribution. ( Mode would 1 for above example)
# 4. Skewness: A measure of symmetry.
# 5. Kurtosis: A measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution

# %% [markdown]
# ## Skewness
# It is the degree of distortion from the symmetrical bell curve or the normal distribution. It measures the lack of symmetry in data distribution.
# It differentiates extreme values in one versus the other tail. A symmetrical distribution will have a skewness of 0.
#
# 1. Positive Skewness means when the tail on the right side of the distribution is longer or fatter. The mean and median will be greater than the mode.
# 1. Negative Skewness is when the tail of the left side of the distribution is longer or fatter than the tail on the right side. The mean and median will be less than the mode.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Understanding Mean and Standar Deviation with Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Now Lets try explaining each of the Columns
#
# 1. First Columns Shows the Max Marks scored by A B C D in Exams
# 1. Second Columns Shows the Difference of Scored - Mean ( Mean is 12 /4 = 3 here )
# 1. Third Columns is Square of the Columns
# 1. Standard Deviation is Calculated in 2 ways One Mean of square difference and their Standard Deviate so here ( 9 + 1+ 0 +4) which 14/4 and Square root of it
# 1. Mean of Sample is same only in denomitor is reduced by so in above case 14/4-1 which 2.16 in this Case
# 1. Variance is Nothing Max - Min of Sample here max is 6 and Means is 1 so variance 6 -1
# 1. With Increase in Sample Data points tends to fall on Normal Distribution
# 1. Incase of Normal Distribution Mean +- Standard Deviation(SD)   68% Data Fall in it
# 1. Incase of Normal Distribution Mean +- 2(Standard Deviation(SD) 95% Data Fall in it
# 1. Incase of Normal Distribution Mean +- 3(Standard Deviation(SD) 99% Data Fall in it

# %% [markdown]
# ## Interquartile Range
# 1. The interquartile range (IQR) is the difference between the first quartile and third quartile. The formula for this is: IQR = Q3 - Q1
# 1. The interquartile range (IQR), also called as midspread or middle 50%, or technically H-spread is the difference between the third quartile (Q3) and the first quartile (Q1). It covers the center of the distribution and contains 50% of the observations. IQR = Q3 – Q1
# 1.

# %% [markdown]
# ## Calculation
# 1. Data is 75, 69, 56, 46, 47, 79, 92, 97, 89, 88, 36, 96, 105, 32, 116, 101, 79, 93, 91, 112
# 1. After sorting the above data set:
# 1. 32, 36, 46, 47, 56, 69, 75, 79, 79, 88, 89, 91, 92, 93, 96, 97, 101, 105, 112, 116
# 1. Here the total number of terms is 20.
# 1. The second quartile (Q2) or the median of the above data is (88 + 89) / 2 = 88.5
# 1. The first quartile (Q1) is median of first n i.e. 10 terms (or n i.e. 10 smallest values) = 62.5
# 1. The third quartile (Q3) is the median of n i.e. 10 largest values (or last n i.e. 10 values) = 96.5
# 1. Then, IQR = Q3 – Q1 = 96.5 – 62.5 = 34.0

# %%
## We have a random list
List1 =[ 75, 69, 56, 46, 47, 79, 92, 97, 89, 88, 36, 96, 105, 32, 116, 101, 79, 93, 91, 112 ]
## Sorting the List 
List1=sorted(List1)
## Caluculating total of list
len(List1)
## Median is 20 + 1 /2 which 10 + 11 /2 ie. 
Q2=(List1[9]+List1[10])/2 ## Calculating Interquartile range for 10 and 11 item 

print("Values of List1 is :"List1)
print("Median or Quartlie 2 is :",Q2)
### Q1 Calculation Here there 10 to left of 88 and 10 to right 
## Q1 is 10/2 5 so value at 5 and 6th Position
Q1=(List1[4]+List1[5])/2

Q3=[89, 91, 92, 93, 96, 97, 101, 105, 112, 116]
Q3=(Q3[4]+Q3[5])/2

IQR=Q3 - Q1
IQR

print("We can say that ")
# Out:
# [32, 36, 46, 47, 56, 69, 75, 79, 79, 88, 89, 91, 92, 93, 96, 97, 101, 105, 112, 116]
# 88.5
# 56 69
# 34.0

# %%
# Simple method of Calculating Interquarltile Range
import numpy as np
  
data = [32, 36, 46, 47, 56, 69, 75, 79, 79, 88, 89, 91, 92, 93, 96, 97, 101, 105, 112, 116]


print(len(data))
# There 20 Value First quartile (Q1)
Q1 = np.median(data[:10])
  
# Third quartile (Q3)
Q3 = np.median(data[10:])

# Interquartile range (IQR)
IQR = Q3 - Q1

print("Values of List :",data)
print("Median is ",np.median(data))
print(f"Quartile is {Q1} and Q3 is {Q3} and Q3 -Q1={IQR}")
# Out:
# 20
# Values of List : [32, 36, 46, 47, 56, 69, 75, 79, 79, 88, 89, 91, 92, 93, 96, 97, 101, 105, 112, 116]
# Median is  88.5
# Quartile is 62.5 and Q3 is 96.5 and Q3 -Q1=34.0

# %% [markdown]
# ## The Significance of the Interquartile Range
# 1. The range gives us a measurement of how spread out the entirety of our data set is. The interquartile range, which tells us how far apart the first and third quartile are, indicates how spread out the middle 50% of our set of data is.
# 1. The interquartile range is often used to find outliers in data. Outliers here are defined as observations that fall below Q1 − 1.5 IQR or above Q3 + 1.5 IQR. In a boxplot, the highest and lowest occurring value within this limit are indicated by whiskers of the box (frequently with an additional bar at the end of the whisker) and any outliers as individual points.
# 1.  In a boxplot, the highest and lowest occurring value within this limit are indicated by whiskers of the box (frequently with an additional bar at the end of the whisker) and any outliers as individual points.

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
sns.boxplot(x=data)
print("Mean is :",sum(data)/len(data))
print("Median is ",np.median(data))
print("First Quartile is :",Q1)
print("Third Quartile is :",Q3)
print("Inter Quartile Range is",IQR)
### Outliers finding in here
print(f"Outliesr are  below :{Q1 - (1.5*IQR)} ")
print(f"Outliesr are  Above :{Q3 + (1.5*IQR)} ")
print(data)
print("We can See there are no outliers in our Data")
# Out:
# Mean is : 79.95
# Median is  88.5
# First Quartile is : 62.5
# Third Quartile is : 96.5
# Inter Quartile Range is 34.0
# Outliesr are  below :11.5
# Outliesr are  Above :147.5
# [32, 36, 46, 47, 56, 69, 75, 79, 79, 88, 89, 91, 92, 93, 96, 97, 101, 105, 112, 116]
# We can See there are no outliers in our Data

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('CardioGoodFitness.csv')
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ## Observations:
#
# 1. Mean Customer age is about 29 years old, and customer ages concentrate between 24 and 33 ( Inter Quartile Range ).
# 1. Mean Customer education is approxiamtely 16 years (Bachelor's Degree), with IQR ranging between 14-16 years.
# 1. Majority of customers have annual incomes between approx. 45k-60k.(IQR)
# 1. Customers expect to run between 66 - 115 (IQR) miles on their treadmill, with average customer expecting to run 103 miles.

# %%
## Finding Different Values 
print("Mean :",df['Age'].mean())
print("Standar Deviation ",df['Age'].std())
print("Median :",np.median(df['Age']))
Q1=24
Q3=33
IQR=Q3 -Q1
print(f"Q1={Q1} and Q3 ={Q3} and Interquirtie Range Q3 -Q1 = {Q3 -Q1}")
## Now Lets Identify Outliers 
print(f"Outliesr are  below :{Q1 - (1.5*IQR)} ")
print(f"Outliesr are  Above :{Q3 + (1.5*IQR)} ")
# Out:
# Mean : 28.788888888888888
# Standar Deviation  6.943498135399795
# Median : 26.0
# Q1=24 and Q3 =33 and Interquirtie Range Q3 -Q1 = 9
# Outliesr are  below :10.5
# Outliesr are  Above :46.5

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Narendra Sharma\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# ## Check skew of quantitative variables

# %%
#check skew
df.skew()
# Out:
# Age          0.982161
# Education    0.622294
# Usage        0.739494
# Fitness      0.454800
# Income       1.291785
# Miles        1.724497
# dtype: float64

# %% [markdown]
# ## Observations:
# 1. Age, Education, and Usage are moderately positively skewed (0.5 < x < 1.0).
# 1. Income and Miles are highly positively skewed (x > 1.0).

# %%
df['Education'].value_counts().plot(kind='bar',title="Number of Years of Education")
# Out:
# <AxesSubplot:title={'center':'Number of Years of Education'}>

# %%
sns
